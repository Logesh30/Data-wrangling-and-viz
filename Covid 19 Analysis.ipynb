# %%
Title: Problem for Covid - 19 Data Analysis Project using Python
Dataset link :
###Url = https://raw.githubusercontent.com/SR1608/Datasets/main/coviddata.csv
Perform following analysis on above dataset :
1. Import the dataset using Pandas from above mentioned url.

# %% [markdown]
# # Importing dataset and libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

url='https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %%
covid=pd.read_csv(url,index_col=0)

# %% [markdown]
# # High Level Data Understanding

# %% [markdown]
# # no. of rows & columns in the dataset

# %%
covid.shape
# Out:
# (57394, 48)

# %% [markdown]
# #  Data types of columns.

# %%
covid.dtypes
# Out:
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# hosp_patients_per_million             float64
# ...

# %% [markdown]
# # Info & describe of data in dataframe.

# %%
covid.info
# Out:
# <bound method DataFrame.info of          continent       location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN        0.0
# AFG           Asia    Afghanistan  01/01/20          NaN        0.0
# AFG           Asia    Afghanistan  02/01/20          NaN        0.0
# AFG           Asia    Afghanistan  03/01/20          NaN        0.0
# AFG           Asia    Afghanistan  04/01/20          NaN        0.0
# ...            ...            ...       ...          ...        ...
# NaN            NaN  International  13/11/20        696.0        NaN
# NaN            NaN  International  14/11/20        696.0        NaN
# NaN            NaN  International  15/11/20        696.0        NaN
# NaN            NaN  International  16/11/20        696.0        NaN
# NaN            NaN  International  17/11/20        696.0        NaN
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
covid.describe
# Out:
# <bound method NDFrame.describe of          continent       location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN        0.0
# AFG           Asia    Afghanistan  01/01/20          NaN        0.0
# AFG           Asia    Afghanistan  02/01/20          NaN        0.0
# AFG           Asia    Afghanistan  03/01/20          NaN        0.0
# AFG           Asia    Afghanistan  04/01/20          NaN        0.0
# ...            ...            ...       ...          ...        ...
# NaN            NaN  International  13/11/20        696.0        NaN
# NaN            NaN  International  14/11/20        696.0        NaN
# NaN            NaN  International  15/11/20        696.0        NaN
# NaN            NaN  International  16/11/20        696.0        NaN
# NaN            NaN  International  17/11/20        696.0        NaN
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %% [markdown]
# # Low Level Data Understanding :

# %% [markdown]
# # count of unique values in location column.

# %%
covid.location.nunique()
# Out:
# 216

# %% [markdown]
# #  continent that has maximum frequency using values counts.

# %%
covid.continent.value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %% [markdown]
# # maximum & mean value in 'total_cases'.

# %%
mean=covid.total_cases.mean()
maximum=covid.total_cases.max()
print("Mean = ",mean, "Max =",maximum)
# Out:
# Mean =  167797.3688753302 Max = 55154651.0

# %% [markdown]
# # 25%,50% & 75% quartile value in 'total_deaths'.

# %%
Q1=covid.quantile(.25)
Q2=covid.quantile(.50)
Q3=covid.quantile(.75)

# %%
Q1
# Out:
# total_cases                           1.800000e+02
# new_cases                             0.000000e+00
# new_cases_smoothed                    8.570000e-01
# total_deaths                          1.300000e+01
# new_deaths                            0.000000e+00
# new_deaths_smoothed                   0.000000e+00
# total_cases_per_million               9.003300e+01
# new_cases_per_million                 0.000000e+00
# new_cases_smoothed_per_million        2.600000e-01
# total_deaths_per_million              3.977750e+00
# new_deaths_per_million                0.000000e+00
# new_deaths_smoothed_per_million       0.000000e+00
# reproduction_rate                     8.700000e-01
# icu_patients                          9.000000e+00
# icu_patients_per_million              1.683750e+00
# hosp_patients                         3.800000e+01
# hosp_patients_per_million             1.055400e+01
# weekly_icu_admissions                 4.027000e+00
# ...

# %%
Q2
# Out:
# total_cases                           2.070000e+03
# new_cases                             1.400000e+01
# new_cases_smoothed                    1.942900e+01
# total_deaths                          8.400000e+01
# new_deaths                            0.000000e+00
# new_deaths_smoothed                   2.860000e-01
# total_cases_per_million               5.936630e+02
# new_cases_per_million                 2.194000e+00
# new_cases_smoothed_per_million        3.863000e+00
# total_deaths_per_million              2.038300e+01
# new_deaths_per_million                0.000000e+00
# new_deaths_smoothed_per_million       2.800000e-02
# reproduction_rate                     1.040000e+00
# icu_patients                          4.800000e+01
# icu_patients_per_million              5.901000e+00
# hosp_patients                         2.130000e+02
# hosp_patients_per_million             3.554800e+01
# weekly_icu_admissions                 2.577800e+01
# ...

# %%
Q3
# Out:
# total_cases                           2.235675e+04
# new_cases                             2.350000e+02
# new_cases_smoothed                    2.452860e+02
# total_deaths                          7.270000e+02
# new_deaths                            4.000000e+00
# new_deaths_smoothed                   4.000000e+00
# total_cases_per_million               3.487050e+03
# new_cases_per_million                 2.594100e+01
# new_cases_smoothed_per_million        2.967850e+01
# total_deaths_per_million              9.057125e+01
# new_deaths_per_million                2.940000e-01
# new_deaths_smoothed_per_million       4.200000e-01
# reproduction_rate                     1.220000e+00
# icu_patients                          2.930000e+02
# icu_patients_per_million              1.746200e+01
# hosp_patients                         1.617000e+03
# hosp_patients_per_million             9.338600e+01
# weekly_icu_admissions                 2.330910e+02
# ...

# %% [markdown]
# # continent that  has maximum 'human_development_index'.

# %%
covid[covid.human_development_index == covid.human_development_index.max()].head(1)['continent']
# Out:
# iso_code
# NOR    Europe
# Name: continent, dtype: object

# %% [markdown]
# # continent that has minimum 'gdp_per_capita'.

# %%
covid[covid.gdp_per_capita==covid.gdp_per_capita.min()]['continent'].head(1)
# Out:
# iso_code
# CAF    Africa
# Name: continent, dtype: object

# %% [markdown]
# # 4. Filtering dataframe with only this columns ['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']

# %%
covid_upd=covid.filter(['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
covid_upd
# Out:
#          continent       location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN           NaN
# AFG           Asia    Afghanistan  01/01/20          NaN           NaN
# AFG           Asia    Afghanistan  02/01/20          NaN           NaN
# AFG           Asia    Afghanistan  03/01/20          NaN           NaN
# AFG           Asia    Afghanistan  04/01/20          NaN           NaN
# ...            ...            ...       ...          ...           ...
# NaN            NaN  International  13/11/20        696.0           7.0
# NaN            NaN  International  14/11/20        696.0           7.0
# NaN            NaN  International  15/11/20        696.0           7.0
# NaN            NaN  International  16/11/20        696.0           7.0
# NaN            NaN  International  17/11/20        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Removing all duplicates observations

# %%
covid_upd.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of          continent       location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN           NaN
# AFG           Asia    Afghanistan  01/01/20          NaN           NaN
# AFG           Asia    Afghanistan  02/01/20          NaN           NaN
# AFG           Asia    Afghanistan  03/01/20          NaN           NaN
# AFG           Asia    Afghanistan  04/01/20          NaN           NaN
# ...            ...            ...       ...          ...           ...
# NaN            NaN  International  13/11/20        696.0           7.0
# NaN            NaN  International  14/11/20        696.0           7.0
# NaN            NaN  International  15/11/20        696.0           7.0
# NaN            NaN  International  16/11/20        696.0           7.0
# NaN            NaN  International  17/11/20        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
# # Find missing values in all columns

# %%
covid_upd.isnull()
# Out:
#           continent  location   date  total_cases  total_deaths  \
# iso_code
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# ...             ...       ...    ...          ...           ...
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
#
#           gdp_per_capita  human_development_index
# iso_code
# AFG                False                    False
# AFG                False                    False
# ...

# %% [markdown]
# # Remove all observations where continent column value is missing

# %%
covid_upd.dropna(subset=['continent'],inplace=True)

# %% [markdown]
# # Fill all missing values with 0

# %%
covid_upd.fillna(0,inplace=True)
covid_upd
# Out:
#          continent     location       date  total_cases  total_deaths  \
# iso_code
# AFG           Asia  Afghanistan 2019-12-31          0.0           0.0
# AFG           Asia  Afghanistan 2020-01-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-02-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-03-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-04-01          0.0           0.0
# ...            ...          ...        ...          ...           ...
# ZWE         Africa     Zimbabwe 2020-11-13       8696.0         255.0
# ZWE         Africa     Zimbabwe 2020-11-14       8765.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-15       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-16       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#           gdp_per_capita  human_development_index  month
# iso_code
# ...

# %% [markdown]
# # Date time format :

# %% [markdown]
# #  Converting date column in datetime format using pandas.to_datetime

# %%
covid_upd['date']=pd.to_datetime(covid_upd['date'])

# %%
covid_upd
# Out:
#          continent     location       date  total_cases  total_deaths  \
# iso_code
# AFG           Asia  Afghanistan 2019-12-31          0.0           0.0
# AFG           Asia  Afghanistan 2020-01-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-02-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-03-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-04-01          0.0           0.0
# ...            ...          ...        ...          ...           ...
# ZWE         Africa     Zimbabwe 2020-11-13       8696.0         255.0
# ZWE         Africa     Zimbabwe 2020-11-14       8765.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-15       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-16       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#           gdp_per_capita  human_development_index  month
# iso_code
# ...

# %% [markdown]
# # Creating new column month after extracting month data from datecolumn.

# %%
covid_upd['month']=covid_upd['date'].dt.month
covid_upd
# Out:
#          continent     location       date  total_cases  total_deaths  \
# iso_code
# AFG           Asia  Afghanistan 2019-12-31          0.0           0.0
# AFG           Asia  Afghanistan 2020-01-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-02-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-03-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-04-01          0.0           0.0
# ...            ...          ...        ...          ...           ...
# ZWE         Africa     Zimbabwe 2020-11-13       8696.0         255.0
# ZWE         Africa     Zimbabwe 2020-11-14       8765.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-15       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-16       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#           gdp_per_capita  human_development_index  month
# iso_code
# ...

# %% [markdown]
# # Data Aggregation:

# %% [markdown]
# #  max value in all columns using groupby function on 'continent' column and Storing the result in a new dataframe named 'df_groupby'.

# %%
covid_groupby=covid_upd.groupby('continent').max()
print(covid_groupby)
# Out:
#                                    location       date  total_cases  \
# continent
# Africa                             Zimbabwe 2020-12-11     752269.0
# Asia                                  Yemen 2020-12-11    8874290.0
# Europe                              Vatican 2020-12-11    1991233.0
# North America  United States Virgin Islands 2020-12-11   11205486.0
# Oceania                   Wallis and Futuna 2020-12-11      27750.0
# South America                     Venezuela 2020-12-11    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index  month  \
# continent
# Africa              20314.0       26382.287                    0.797     12
# Asia               130519.0      116935.600                    0.933     12
# Europe              52147.0       94277.965                    0.953     12
# North America      247220.0       54225.446                    0.926     12
# Oceania               907.0       44648.710                    0.939     12
# ...

# %%
covid_groupby=covid_cont.reset_index()
covid_groupby
# Out:
#    level_0  index      continent                      location       date  \
# 0        0      0         Africa                      Zimbabwe 2020-12-11
# 1        1      1           Asia                         Yemen 2020-12-11
# 2        2      2         Europe                       Vatican 2020-12-11
# 3        3      3  North America  United States Virgin Islands 2020-12-11
# 4        4      4        Oceania             Wallis and Futuna 2020-12-11
# 5        5      5  South America                     Venezuela 2020-12-11
#
#    total_cases  total_deaths  gdp_per_capita  human_development_index  month
# 0     752269.0       20314.0       26382.287                    0.797     12
# 1    8874290.0      130519.0      116935.600                    0.933     12
# 2    1991233.0       52147.0       94277.965                    0.953     12
# 3   11205486.0      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# # Feature Engineering :

# %% [markdown]
# # Creating a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'

# %%
covid_upd['total_deaths_to_total_cases']=covid_upd['total_deaths']/covid_upd['total_cases']
covid_upd.fillna(0,inplace=True)
covid_upd
# Out:
#          continent     location       date  total_cases  total_deaths  \
# iso_code
# AFG           Asia  Afghanistan 2019-12-31          0.0           0.0
# AFG           Asia  Afghanistan 2020-01-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-02-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-03-01          0.0           0.0
# AFG           Asia  Afghanistan 2020-04-01          0.0           0.0
# ...            ...          ...        ...          ...           ...
# ZWE         Africa     Zimbabwe 2020-11-13       8696.0         255.0
# ZWE         Africa     Zimbabwe 2020-11-14       8765.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-15       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-16       8786.0         257.0
# ZWE         Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#           gdp_per_capita  human_development_index  month  \
# iso_code
# ...

# %% [markdown]
# # Data Visualization :

# %% [markdown]
# # Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.

# %%
sns.distplot(covid_upd['gdp_per_capita'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %% [markdown]
# #  scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
sns.scatterplot(data=covid_upd,x='total_cases',y='gdp_per_capita')
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='gdp_per_capita'>

# %% [markdown]
# #  Pairplot on df_groupby dataset.

# %%
sns.pairplot(data=covid_groupby)

# %% [markdown]
# # bar plot of 'continent' column with 'total_cases' .

# %%
sns.catplot(data=covid_upd,x='continent',y='total_cases',kind='bar')

# %% [markdown]
# # Saving the df_groupby dataframe in your local drive using pandas.to_csv function .

# %%
covid_upd.to_csv('continentwise.csv')
